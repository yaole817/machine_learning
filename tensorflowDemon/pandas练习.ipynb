# %% [markdown]
# # panads 练习

# %%
import pandas as pd
import tushare as ts
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
yili = ts.get_hist_data('600887')
yili = yili.sort_index(ascending=True)
yili_open = yili["open"]
# yili.plot()
yili_open.plot(figsize=(14, 9))

# %%
yili.head(5)
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2016-03-22  14.53  14.54  14.40  14.35  330391.25         -0.19     -1.30
# 2016-03-23  14.40  14.67  14.51  14.38  315985.84          0.12      0.83
# 2016-03-24  14.50  14.50  14.12  14.11  511789.03         -0.40     -2.75
# 2016-03-25  14.11  14.25  14.17  14.05  204693.61          0.05      0.35
# 2016-03-28  14.24  14.54  14.10  14.08  418236.91         -0.07     -0.49
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20
# date
# 2016-03-22  14.400  14.400  14.400  330391.25  330391.25  330391.25
# 2016-03-23  14.455  14.455  14.455  323188.55  323188.55  323188.55
# 2016-03-24  14.343  14.343  14.343  386055.37  386055.37  386055.37
# 2016-03-25  14.300  14.300  14.300  340714.93  340714.93  340714.93
# 2016-03-28  14.260  14.260  14.260  356219.33  356219.33  356219.33

# %%
# 画出5日，10日，20 日均线和每日均线的对比
yili["close"].plot(figsize=(19, 5), color="black")
# yili["ma5"].plot(figsize=(19, 5), color="red")
yili["ma10"].plot(figsize=(19, 5), color="green")
# yili["ma20"].plot(figsize=(19, 5), color="blue")

# %%
yili.columns
# Out:
# Index(['open', 'high', 'close', 'low', 'volume', 'price_change', 'p_change',
#        'ma5', 'ma10', 'ma20', 'v_ma5', 'v_ma10', 'v_ma20'],
#       dtype='object')

# %%
yili = yili.sort_index(ascending=True)

# %%
yili_open = yili["volume"].plot(title = "yili")
fig = yili_open.get_figure()
fig.set_size_inches(13.5, 9)
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
yili.plot(["open"])
